# %%
import mitsuba as mi

# %%
mi.set_variant("llvm_ad_rgb")

# %%
scene = mi.load_file("./projectFiles/scene.xml")

# %%
image = mi.render(scene, spp=256)

# %%
import matplotlib.pyplot as plt

plt.axis("off")
plt.imshow(image ** (1.0 / 2.2)); # approximate sRGB tonemapping
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
scene = mi.load_file("./nlos_room/scene.xml")
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Input In [12], in <cell line: 1>()
# ----> 1 scene = mi.load_file("./nlos_room/scene.xml")
#
# RuntimeError: ​[xml.cpp:215] Error while loading "./nlos_room/scene.xml" (at line 36, col 4): invalid spectrum (expected wavelength:value pairs).

# %%
mi.variants()
# Out:
# ['scalar_rgb', 'scalar_spectral', 'cuda_ad_rgb', 'llvm_ad_rgb']

# %%
import matplotlib.pyplot as plt

plt.axis("off")
plt.imshow(image ** (1.0 / 2.2)); # approximate sRGB tonemapping
